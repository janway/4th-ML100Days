# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y1, yp):
    mse = sum(np.power((y1 - yp), 2)) / len(y1)
    return mse

def mean_absolute_error(y1, yp):
    mae = sum(abs(y1 - yp), 2) / len(y1)
    return mae

# %%
w = 4
b = 0.5
x_lin = np.linspace(0, 100, 101)
rnd = np.random.randn(101)
y = (x_lin + rnd * 5) * w + b
y_hat = x_lin * w + b

plt.plot(x_lin, y, 'b.', label='data point')
plt.title('data point shown here')
plt.plot(x_lin, y_hat, 'r-', label='prediction')
plt.legend(loc=2)
plt.show()

# %%
MSE = mean_squared_error(y,y_hat)
print ("MSE=%.2f" % MSE)

MAE = mean_absolute_error(y, y_hat)
print ("MAE=%.2f" % MAE)
# Out:
# MSE=338.02
# MAE=15.16
