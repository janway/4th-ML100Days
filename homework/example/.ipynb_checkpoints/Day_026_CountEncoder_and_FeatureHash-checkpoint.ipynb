# %% [markdown]
# # 範例 : (Kaggle)鐵達尼生存預測

# %% [markdown]
# # [教學目標]
# - 以下用鐵達尼生存預測資料, 觀察計數編碼與特徵雜湊的效果

# %% [markdown]
# # [範例重點]
# - 了解計數編碼的寫作方式(In[5], Out[5]), 以及計數編碼搭配邏輯斯迴歸對於測結果有什麼影響 (In[7], Out[7])
# - 觀察 雜湊編碼, 以及 計數編碼+雜湊編碼 分別搭配邏輯斯迴歸對於測結果有什麼影響 (In[8], Out[8], In[9], Out[9])

# %%
# 做完特徵工程前的所有準備
import pandas as pd
import numpy as np
import copy, time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

data_path = '../../data/FeatureType/'
df_train = pd.read_csv(data_path + 'titanic_train.csv')
df_test = pd.read_csv(data_path + 'titanic_test.csv')

train_Y = df_train['Survived']
ids = df_test['PassengerId']
df_train = df_train.drop(['PassengerId', 'Survived'] , axis=1)
df_test = df_test.drop(['PassengerId'] , axis=1)
df = pd.concat([df_train,df_test])
df.head()
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171   7.2500   NaN        S
# 1      1      0          PC 17599  71.2833   C85        C
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3      1      0            113803  53.1000  C123        S
# 4      0      0            373450   8.0500   NaN        S

# %%
#只取類別值 (object) 型欄位, 存於 object_features 中
object_features = []
for dtype, feature in zip(df.dtypes, df.columns):
    if dtype == 'object':
        object_features.append(feature)
print(f'{len(object_features)} Object Features : {object_features}\n')

# 只留類別型欄位
df = df[object_features]
df = df.fillna('None')
train_num = train_Y.shape[0]
df.head()
# Out:
# 5 Object Features : ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171  None        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282  None        S
# 3            113803  C123        S
# 4            373450  None        S

# %%
# 觀察欄位相異值數量
df.select_dtypes(include=["object"]).apply(pd.Series.nunique)
# Out:
# Name        1307
# Sex            2
# Ticket       929
# Cabin        187
# Embarked       4
# dtype: int64

# %%
# 對照組 : 標籤編碼 + 邏輯斯迴歸
df_temp = pd.DataFrame()
for c in df.columns:
    df_temp[c] = LabelEncoder().fit_transform(df[c])
train_X = df_temp[:train_num]
estimator = LogisticRegression()
print(cross_val_score(estimator, train_X, train_Y, cv=5).mean())
df_temp.head()
# Out:
# 0.780004837244799
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#    Name  Sex  Ticket  Cabin  Embarked
# 0   155    1     720    185         3
# 1   286    0     816    106         0
# 2   523    0     914    185         3
# 3   422    0      65     70         3
# 4    22    1     649    185         3

# %%
aa = df.groupby(['Ticket'])

for key, df0 in aa:
    print(f'key = {key},shape={df.shape}')
# Out:
# key = 110152
# key = 110413
# key = 110465
# key = 110469
# key = 110489
# key = 110564
# key = 110813
# key = 111163
# key = 111240
# key = 111320
# key = 111361
# key = 111369
# key = 111426
# key = 111427
# key = 111428
# key = 112050
# key = 112051
# key = 112052
# key = 112053
# key = 112058
# key = 112059
# key = 112277
# key = 112377
# key = 112378
# key = 112379
# key = 112901
# key = 113028
# key = 113038
# key = 113043
# key = 113044
# key = 113050
# key = 113051
# key = 113054
# key = 113055
# key = 113056
# key = 113059
# key = 113501
# key = 113503
# key = 113505
# key = 113509
# key = 113510
# key = 113514
# key = 113572
# key = 113760
# key = 113767
# key = 113773
# key = 113776
# key = 113778
# key = 113780
# key = 113781
# key = 113783
# key = 113784
# key = 113786
# key = 113787
# key = 113788
# key = 113789
# key = 113790
# key = 113791
# key = 113792
# key = 113794
# key = 113795
# key = 113796
# key = 113798
# key = 113800
# key = 113801
# key = 113803
# key = 113804
# key = 113806
# key = 113807
# key = 11668
# key = 11751
# key = 11752
# key = 11753
# key = 11755
# key = 11765
# key = 11767
# key = 11769
# key = 11770
# key = 11771
# key = 11774
# key = 11778
# key = 11813
# key = 11967
# key = 1222
# key = A.5. 11206
# key = A.5. 18509
# key = A.5. 3236
# key = A/4 31416
# key = A/4 45380
# key = A/4 48871
# key = A/4 48873
# key = A/4. 20589
# key = A/4. 34244
# key = A/4. 39886
# key = A/5 1478
# key = A/5 21171
# key = A/5 21172
# key = A/5 21173
# key = A/5 21174
# key = A/5 21175
# key = A/5 2466
# key = A/5 2817
# key = A/5 3536
# key = A/5 3540
# key = A/5 3594
# key = A/5 3902
# key = A/5. 10482
# key = A/5. 13032
# key = A/5. 2151
# key = A/5. 3336
# key = A/5. 3337
# key = A/5. 851
# key = A/S 2816
# key = A4. 54510
# key = AQ/3. 30631
# key = AQ/4 3130
# key = C 17368
# key = C 17369
# key = C 4001
# key = C 7075
# key = C 7076
# key = C 7077
# key = C.A. 15185
# key = C.A. 17248
# key = C.A. 18723
# key = C.A. 2315
# key = C.A. 24579
# key = C.A. 24580
# key = C.A. 2673
# key = C.A. 29178
# key = C.A. 29395
# key = C.A. 29566
# key = C.A. 30769
# key = C.A. 31026
# key = C.A. 31029
# key = C.A. 31030
# key = C.A. 31921
# key = C.A. 33111
# key = C.A. 33112
# key = C.A. 33595
# key = C.A. 34050
# key = C.A. 34260
# key = C.A. 34644
# key = C.A. 34651
# key = C.A. 37671
# key = C.A. 42795
# key = C.A. 49867
# key = C.A. 5547
# key = C.A. 6212
# key = C.A./SOTON 34068
# key = CA 2144
# key = CA 31352
# key = CA. 2314
# key = CA. 2343
# key = F.C. 12750
# key = F.C. 12998
# key = F.C.C. 13528
# key = F.C.C. 13529
# key = F.C.C. 13531
# key = F.C.C. 13534
# key = F.C.C. 13540
# key = Fa 265302
# key = LINE
# key = LP 1588
# key = P/PP 3381
# key = PC 17318
# key = PC 17473
# key = PC 17474
# key = PC 17475
# key = PC 17476
# key = PC 17477
# key = PC 17482
# key = PC 17483
# key = PC 17485
# key = PC 17531
# key = PC 17558
# key = PC 17562
# key = PC 17569
# key = PC 17572
# key = PC 17580
# key = PC 17582
# key = PC 17585
# key = PC 17590
# key = PC 17591
# key = PC 17592
# key = PC 17593
# key = PC 17594
# key = PC 17595
# key = PC 17596
# key = PC 17597
# key = PC 17598
# key = PC 17599
# key = PC 17600
# key = PC 17601
# key = PC 17603
# key = PC 17604
# key = PC 17605
# key = PC 17606
# key = PC 17607
# key = PC 17608
# key = PC 17609
# key = PC 17610
# key = PC 17611
# key = PC 17612
# key = PC 17613
# key = PC 17754
# key = PC 17755
# key = PC 17756
# key = PC 17757
# key = PC 17758
# key = PC 17759
# key = PC 17760
# key = PC 17761
# key = PP 4348
# key = PP 9549
# key = S.C./A.4. 23567
# key = S.C./PARIS 2079
# key = S.O./P.P. 2
# key = S.O./P.P. 251
# key = S.O./P.P. 3
# key = S.O./P.P. 751
# key = S.O./P.P. 752
# key = S.O.C. 14879
# key = S.O.P. 1166
# key = S.P. 3464
# key = S.W./PP 752
# key = SC 14888
# key = SC 1748
# key = SC/A.3 2861
# key = SC/A4 23568
# key = SC/AH 29037
# key = SC/AH 3085
# key = SC/AH Basle 541
# key = SC/PARIS 2131
# key = SC/PARIS 2133
# key = SC/PARIS 2146
# key = SC/PARIS 2147
# key = SC/PARIS 2148
# key = SC/PARIS 2149
# key = SC/PARIS 2159
# key = SC/PARIS 2166
# key = SC/PARIS 2167
# key = SC/PARIS 2168
# key = SC/Paris 2123
# key = SC/Paris 2163
# key = SCO/W 1585
# key = SO/C 14885
# key = SOTON/O.Q. 3101262
# key = SOTON/O.Q. 3101263
# key = SOTON/O.Q. 3101305
# key = SOTON/O.Q. 3101306
# key = SOTON/O.Q. 3101307
# key = SOTON/O.Q. 3101308
# key = SOTON/O.Q. 3101309
# key = SOTON/O.Q. 3101310
# key = SOTON/O.Q. 3101311
# key = SOTON/O.Q. 3101312
# key = SOTON/O.Q. 3101314
# key = SOTON/O.Q. 3101315
# key = SOTON/O.Q. 392078
# key = SOTON/O.Q. 392087
# key = SOTON/O2 3101272
# key = SOTON/O2 3101284
# key = SOTON/O2 3101287
# key = SOTON/OQ 3101316
# key = SOTON/OQ 3101317
# key = SOTON/OQ 392076
# key = SOTON/OQ 392082
# key = SOTON/OQ 392083
# key = SOTON/OQ 392086
# key = SOTON/OQ 392089
# key = SOTON/OQ 392090
# key = STON/O 2. 3101268
# key = STON/O 2. 3101269
# key = STON/O 2. 3101273
# key = STON/O 2. 3101274
# key = STON/O 2. 3101275
# key = STON/O 2. 3101280
# key = STON/O 2. 3101285
# key = STON/O 2. 3101286
# key = STON/O 2. 3101288
# key = STON/O 2. 3101289
# key = STON/O 2. 3101291
# key = STON/O 2. 3101292
# key = STON/O 2. 3101293
# key = STON/O 2. 3101294
# key = STON/O2. 3101270
# key = STON/O2. 3101271
# key = STON/O2. 3101279
# key = STON/O2. 3101282
# key = STON/O2. 3101283
# key = STON/O2. 3101290
# key = STON/OQ. 369943
# key = SW/PP 751
# key = W./C. 14258
# key = W./C. 14260
# key = W./C. 14263
# key = W./C. 14266
# key = W./C. 6607
# key = W./C. 6608
# key = W./C. 6609
# key = W.E.P. 5734
# key = W/C 14208
# key = WE/P 5735

# %%
# 加上 'Ticket' 欄位的計數編碼
# 第一行 : df.groupby(['Ticket']) 會輸出 df 以 'Ticket' 群聚後的結果, 但因為群聚一類只會有一個值, 因此必須要定義運算
# 例如 df.groupby(['Ticket']).size(), 但欄位名稱會變成 size, 要取別名就需要用語法 df.groupby(['Ticket']).agg({'Ticket_Count':'size'})
# 這樣出來的計數欄位名稱會叫做 'Ticket_Count', 因為這樣群聚起來的 'Ticket' 是 index, 所以需要 reset_index() 轉成一欄
# 因此第一行的欄位, 在第三行按照 'Ticket_Count' 排序後, 最後的 DataFrame 輸出如 Out[5]
count_df = df.groupby(['Ticket'])['Name'].agg({'Ticket_Count':'size'}).reset_index()
# 但是上面資料表結果只是 'Ticket' 名稱對應的次數, 要做計數編碼還需要第二行 : 將上表結果與原表格 merge, 合併於 'Ticket' 欄位
# 使用 how='left' 是完全保留原資料表的所有 index 與順序
df = pd.merge(df, count_df, on=['Ticket'], how='left')
count_df.sort_values(by=['Ticket_Count'], ascending=False).head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version. Use                 named aggregation instead.
#
#     >>> grouper.agg(name_1=func_1, name_2=func_2)
#       Ticket  Ticket_Count
# 0  WE/P 5735             2

# %%
# 印出來看看, 加了計數編碼的資料表 df 有何不同
df.head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked  Ticket_Count
# 0         A/5 21171  None        S             1
# 1          PC 17599   C85        C             2
# 2  STON/O2. 3101282  None        S             1
# 3            113803  C123        S             2
# 4            373450  None        S             1

# %%
# 'Ticket'計數編碼 + 邏輯斯迴歸
df_temp = pd.DataFrame()
for c in object_features:
    df_temp[c] = LabelEncoder().fit_transform(df[c])
df_temp['Ticket_Count'] = df['Ticket_Count']
train_X = df_temp[:train_num]
estimator = LogisticRegression()
print(cross_val_score(estimator, train_X, train_Y, cv=5).mean())
df_temp.head()
# Out:
# 0.7811221556805532
#    Name  Sex  Ticket  Cabin  Embarked  Ticket_Count
# 0   155    1     720    185         3             1
# 1   286    0     816    106         0             2
# 2   523    0     914    185         3             1
# 3   422    0      65     70         3             2
# 4    22    1     649    185         3             1

# %%
# 'Ticket'特徵雜湊 + 邏輯斯迴歸
df_temp = pd.DataFrame()
for c in object_features:
    df_temp[c] = LabelEncoder().fit_transform(df[c])
# 這邊的雜湊編碼, 是直接將 'Ticket' 的名稱放入雜湊函數的輸出數值, 為了要確定是緊密(dense)特徵, 因此除以10後看餘數
# 這邊的 10 是隨機選擇, 不一定要用 10, 同學可以自由選擇購小的數字試看看. 基本上效果都不會太好
df_temp['Ticket_Hash'] = df['Ticket'].map(lambda x:hash(x) % 10)
train_X = df_temp[:train_num]
estimator = LogisticRegression()
print(cross_val_score(estimator, train_X, train_Y, cv=5).mean())
df_temp.head()
# Out:
# 0.7799985601749352
#    Name  Sex  Ticket  Cabin  Embarked  Ticket_Hash
# 0   155    1     720    185         3            2
# 1   286    0     816    106         0            3
# 2   523    0     914    185         3            5
# 3   422    0      65     70         3            1
# 4    22    1     649    185         3            9

# %%
# 'Ticket'計數編碼 + 'Ticket'特徵雜湊 + 邏輯斯迴歸
df_temp = pd.DataFrame()
for c in object_features:
    df_temp[c] = LabelEncoder().fit_transform(df[c])
df_temp['Ticket_Hash'] = df['Ticket'].map(lambda x:hash(x) % 10)
df_temp['Ticket_Count'] = df['Ticket_Count']
train_X = df_temp[:train_num]
estimator = LogisticRegression()
print(cross_val_score(estimator, train_X, train_Y, cv=5).mean())
df_temp.head()
# Out:
# 0.7833820426862029
#    Name  Sex  Ticket  Cabin  Embarked  Ticket_Hash  Ticket_Count
# 0   155    1     720    185         3            2             1
# 1   286    0     816    106         0            3             2
# 2   523    0     914    185         3            5             1
# 3   422    0      65     70         3            1             2
# 4    22    1     649    185         3            9             1

# %% [markdown]
# # 作業1
# * 參考範例，將鐵達尼的艙位代碼( 'Cabin' )欄位使用特徵雜湊 / 標籤編碼 / 計數編碼三種轉換後，
# 與其他類別型欄位一起預估生存機率
#
# # 作業2
# * 承上題，三者比較效果何者最好?
